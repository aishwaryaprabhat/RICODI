# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("survey_results.csv")

# %% [markdown]
# ## Summary of data

# %%
df
# Out:
#     response             Q1       Q2                                Q3  \
# 0          1  North America  30 - 39           Interviewer;Interviewee
# 1          2  North America  18 - 29                       Interviewee
# 2          3           Asia  18 - 29  Interviewer;Interviewee;Observer
# 3          4  North America  30 - 39                       Interviewee
# 4          5  North America  40 - 49           Interviewer;Interviewee
# 5          6  North America  30 - 39                       Interviewee
# 6          7           Asia  30 - 39                       Interviewee
# 7          8  North America  18 - 29           Interviewer;Interviewee
# 8          9           Asia  18 - 29                       Interviewee
# 9         10           Asia  18 - 29  Interviewer;Interviewee;Observer
# 10        11         Europe  18 - 29                       Interviewee
# 11        12  North America  30 - 39                       Interviewee
# ...

# %%
sns.countplot(y="Q1", data=df)

# %%
sns.countplot(y="Q2", data=df)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q3"].to_list()]:
    for element in list_:
        new_list.append(element)
    
sns.countplot(y=new_list)

# %%
sns.catplot(y="Q4", kind="count", data=df)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q5"].to_list()]:
    for element in list_:
        new_list.append(element)
sns.countplot(y=new_list)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q5"].to_list()]:
    for element in list_:
        new_list.append(element)
sns.countplot(y=new_list)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q7"].to_list()]:
    for element in list_:
        new_list.append(element)
sns.countplot(y=new_list)

# %%
new_list = []
for list_ in [x.split(";") for x in df["Q9"].to_list()]:
    for element in list_:
        new_list.append(element)
sns.countplot(y=new_list)

# %%
df["Q8"].dropna().to_list()
# Out:
# ['Codility, a very primitive text editor',
#  'coderpad',
#  'Codility',
#  'coderpad',
#  'na',
#  'Hackerearth, coderbyte',
#  'Other not selected, NA',
#  'CodePen',
#  'Na']

# %%
df["Q6"].dropna().to_list()
# Out:
# ['-', 'na', 'na', 'Other not selected, NA', 'NANA', 'na']
